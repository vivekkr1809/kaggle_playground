# %%
# Logistic Regression Classification - Practice Template
# =====================================================
#
# This notebook provides a complete workflow for classification analysis using logistic regression,
# from data loading to model evaluation and interpretation.

# %%
# Import necessary libraries
# TO DO: Import numpy, pandas, matplotlib and seaborn

# %%
# Set random seed for reproducibility
# Example: np.random.seed(0)

# %%
# 1. Data Loading
# Load the train and test file from say S5Ep3
# train_data = pd.read_csv("path/to/train.csv")

# %%
# 2. Exploratory Data Analysis (EDA)
# ==================================
# Get Summary Statistics

# %%
# Check for missing values

# %%
# Check class distributions

# %%
# Visualize feature distributions by class

# %%
# Perform Correlation analysis

# %%
# Pairplot to visualize relationships between features

# %%
# 3. Data Preprocessing
# =====================

# %%
# Split into train and validation
# from sklearn.model_selection import train_test_split
# X_train, X_val, y_train, y_val = train_test_split(features, labels, test_size = 0.2, random_state = 42)

# %%
# Perform preprocessing for numeric data

# Do missing data imputation: Use median for example

# Normalize the data: Example StandardScaler

# %%
# Perform preprocessing for categorical data

# Do missing data imputation: Use mode for example

# Use One-hot encoding

# %%
# 4. Model Building
# ================
# Build the linear regression model
# From sklearn.linear_model import LogisticRegression
# linear_model = LogisticRegression()

# Handling Class Imbalance (if necessary)
# Check if classes are imbalanced
# Use balanced weighted for class imbalances

# %%
# Train the model
# Use fit()

# %%
# Predict on train, validation and compute the metrics: Accuracy, ROC AUC

# %%
# 5. Model Evaluation
# ==================

# Create a function to evaluate and display metrics

# %%
# 6. Model Tuning
# ==============

# %%
# Hyperparameter tuning using Grid Search
# param_grid = {
#     'classifier__C': [0.001, 0.01, 0.1, 1, 10, 100],
#     'classifier__penalty': ['l1', 'l2', 'elasticnet', None],
#     'classifier__solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
#     'classifier__class_weight': ['balanced', None]
# }
