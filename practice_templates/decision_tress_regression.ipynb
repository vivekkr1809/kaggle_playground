# %%
# Decision Tree Regression - Practice Template
# ============================================
#
# This notebook provides a complete workflow for regression analysis using decision trees,
# from data loading to model evaluation and interpretation.

# %%
# Import necessary libraries
# TO DO: Import numpy, pandas, matplotlib and seaborn

# %%
# Set random seed for reproducibility
# np.random.seed(42)

# %%
# 1. Data Loading
# Load the train and test file from say S5Ep2
# train_data = pd.read_csv("path/to/train.csv")

# %%
# 2. Exploratory Data Analysis (EDA)
# ==================================
# Get Summary Statistics

# %%
# Check for missing values

# %%
# Visualize distributions

# %%
# Correlation analysis

# %%
# Make plots showing features vs targets

# %%
# 3. Data Preprocessing
# =====================

# %%
# Split into train and validation
# from sklearn.model_selection import train_test_split
# X_train, X_val, y_train, y_val = train_test_split(features, labels, test_size = 0.2, random_state = 42)

# %%
# Perform preprocessing for numeric data

# Do missing data imputation: Use median for example

# Normalize the data: Example StandardScaler

# %%
# Perform preprocessing for categorical data

# Do missing data imputation: Use mode for example

# Use One-hot encoding

# %%
# 4. Model Building
# ================
# Use Simple Decision Tree model
# from sklearn.tree import DecisionTreeRegressor, plot_tree
# dt_model = DecisionTreeRegressor(random_state=42)

# %%
# Train the model
# Use fit()

# %%
# Predict on train, validation and compute the metrics: RMSE, R2, Slope

# %%
# Make correlation plot

# Make the residual plot

# %%
# 6. Model Tuning
# ==============

# Define hyperparameter grid
# param_grid = {
#     'model__max_depth': [None, 3, 5, 7, 10],
#     'model__min_samples_split': [2, 5, 10],
#     'model__min_samples_leaf': [1, 2, 4]
# }

# Set estimator
# dt_model = []

# Perform grid search with cross-validation
# grid_search = GridSearchCV(
#     estimator=dt_model,
#     param_distributions=param_grid,
# )

# Fit grid search
# grid_search.fit(X_train, y_train)

# %%
# Get best parameters and model

# %%
# Evaluate the best model

# Evaluate on training set

# Evaluate on test set

# %%
# Summarize your findings
